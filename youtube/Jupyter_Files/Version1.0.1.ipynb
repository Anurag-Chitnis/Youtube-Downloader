# %%
import bs4
import requests as req
import pafy
import os
from time import time

class Youtube_Downloader():
    def __init__(self, url, playlist_name="", _type="Local",folder=os.path.expanduser("~\\Videos").replace("\\", "/")):
        self._url = url 
        self._apikey = pafy.set_api_key("AIzaSyAm6pxYxNJS9oZIxwxGTpptJrP33C9ZyVw")
        self._path = ""
        self._folderType = _type
        self._folderName = folder
        self._playlist_name = playlist_name
        
        print(self._folderName)
        if self._folderType == "Local":
            self._folderName = self._folderName + "/" + "Local"
            if not os.path.exists(self._folderName):
                os.mkdir(self._folderName)
        elif self._folderType == "Playlist":
            self._folderName = self._folderName + "/" + "Playlist"
            if not os.path.exists(self._folderName):
                os.mkdir(self._folderName)
                
           
    def video_details(self):
        details = pafy.new(self._url)
        return details
    
    def download_video(self):
        
        vid_detail = self.video_details()
        best_stream = vid_detail.getbest(preftype="mp4")
        if self._folderType == "Playlist":
            self._path = self._folderName + "/" + self._playlist_name
            self._path = self._path.replace(",", "_").replace("|", "__")
            if not os.path.exists(self._path):
                os.mkdir(self._path)
            else:
                print("Playlist exists")
        else:
            self._path = self._folderName + "/" + vid_detail.title
            if os.path.exists(self._path):
                self._path = self._folderName + "/" + vid_detail.title + str(int(time()))
                self._path = self._path.replace(",", "_").replace("|", "__")
                os.mkdir(self._path)
            else:
                self._path = self._path.replace(",", "_").replace("|", "__") 
                os.mkdir(self._path)
        
        print(self._path)
        best_stream.download(filepath=self._path)

class Youtube_PlayList():
    def __init__(self,url):
        self._urlList = []
        self._playListUrl = url
        self._downloadFolder = ""
        
    def list_returner(self):
        res = req.get(self._playListUrl)
        parsed_data = bs4.BeautifulSoup(res.text, "html.parser")
        self._downloadFolder = parsed_data.findAll('h1')[1].text.strip()
        video_container = parsed_data.findAll("div", {'id': 'content'})
        for container in video_container:
            links = container.findAll('a', {'class': 'pl-video-title-link yt-uix-tile-link yt-uix-sessionlink spf-link'})
            for link in links:
                self._urlList.append("https://www.youtube.com/" + link['href'])
        return self._urlList
    
    def connector(self):
        urlList = []
        urlList = self.list_returner()
        for url in urlList:
            obj = Youtube_Downloader(url, self._downloadFolder, "Playlist")
            obj.download_video()
            
    
def main():
    while True:
        print("-"*10 + "Welcome" + "-"*10)
        print("1. Want to download playlist: ")
        print("2. Want to download a single video")
        print("3. Exit")
        choice = input("Enter your choice: ")
        if choice == "1":
            user_url = input("Enter playlist url: ")
            obj = Youtube_PlayList(user_url)
            obj.connector()
        elif choice == "2":
            user_url = input("Enter video url: ")
            obj = Youtube_Downloader(user_url)
            obj.download_video()
        elif choice == "3":
            break
        else:
            print("Invalid Choice")
        
if __name__ == "__main__":
    main()
# Out:
# ----------Welcome----------
# 1. Want to download playlist:
# 2. Want to download a single video
# 3. Exit
# Enter your choice: 2
# Enter video url: https://www.youtube.com/watch?v=8CdcCD5V-d8
# C:/Users/Anurag/Videos
# C:/Users/Anurag/Videos/Local/Eminem - Venom
#   15,405,476.0 Bytes [100.00%] received. Rate: [3913 KB/s].  ETA: [0 secs]
# ----------Welcome----------
# 1. Want to download playlist:
# 2. Want to download a single video
# 3. Exit
# Enter your choice: 1
# Enter playlist url: https://www.youtube.com/playlist?list=PLillGF-RfqbbJYRaNqeUzAb7QY-IqBKRx
# Python Videos
# C:/Users/Anurag/Videos
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   149,126,678.0 Bytes [100.00%] received. Rate: [3525 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   57,140,741.0 Bytes [100.00%] received. Rate: [4064 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   49,934,853.0 Bytes [100.00%] received. Rate: [2125 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   106,759,225.0 Bytes [100.00%] received. Rate: [2077 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   55,776,486.0 Bytes [100.00%] received. Rate: [3322 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   112,449,284.0 Bytes [100.00%] received. Rate: [2509 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   57,411,061.0 Bytes [100.00%] received. Rate: [4104 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   56,026,637.0 Bytes [100.00%] received. Rate: [4657 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   128,485,758.0 Bytes [100.00%] received. Rate: [3268 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   23,320,403.0 Bytes [100.00%] received. Rate: [3817 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   77,554,191.0 Bytes [100.00%] received. Rate: [4921 KB/s].  ETA: [0 secs]
# Python Videos
# C:/Users/Anurag/Videos
# Playlist exists
# C:/Users/Anurag/Videos/Playlist/Python Videos
#   53,424,338.0 Bytes [100.00%] received. Rate: [4026 KB/s].  ETA: [0 secs]
# ----------Welcome----------
# 1. Want to download playlist:
# 2. Want to download a single video
# 3. Exit

# %%
# Do the above program using multi threading
from threading import Thread
import time

def method():
    i = 0
    while i < 11:
        time.sleep(1)
        i +=1
        print(i)
t1 = Thread(target=method, daemon=True)
t2 = Thread(target=method)

# %%
t1.start()
t2.start()

# %%
path = os.path.expanduser("~\\Videos")
path

# %%
import youtube_dl as y
print(y)
# Out:
# <module 'youtube_dl' from 'C:\\Users\\Anurag\\Anaconda3\\lib\\site-packages\\youtube_dl\\__init__.py'>
